# %%
import pandas as pd

df = pd.DataFrame({
    "x": [2, 3, 4],
    "y": [1, 3, 5]
})

df
# Out:
#    x  y
# 0  2  1
# 1  3  3
# 2  4  5

# %%
import matplotlib.pylab as plt
import numpy as np

figure=plt.figure(figsize=(10, 5))
axis = figure.add_subplot()

# Los datos que se muestran
axis.plot(df.x, df.y,"o",color="#0000FF")  
  
# Las etiquetas
axis.set_xlabel('X', fontsize=15,labelpad=20,color="#003B80")  
axis.set_ylabel('Y', fontsize=15,labelpad=20,color="#003B80")
axis.set_title("Regresión lineal simple", fontsize=20,pad=30,color="#003B80")

# Las etiquetas
axis.set_xlabel('X', fontsize=15,labelpad=20,color="#003B80")  
axis.set_ylabel('Y', fontsize=15,labelpad=20,color="#003B80")
axis.set_title("Regresión lineal simple", fontsize=20,pad=30,color="#003B80")
# Out:
# Text(0.5, 1.0, 'Regresión lineal simple')

# %%
import matplotlib.pylab as plt
import numpy as np

figure=plt.figure(figsize=(10, 5))
axis = figure.add_subplot()

# Los datos que se muestran
axis.plot(df.x, df.y,"o",color="#0000FF")
#axis.plot(x, y1)
axis.hlines(y = 3, xmin = 1.75, xmax = 4.25)
axis.vlines(x = 2, ymin = 1, ymax = 3, color="#FF0000", linewidth = 1)
axis.vlines(x = 4, ymin = 3, ymax = 5, color="#FF0000", linewidth = 1)
axis.text(x = 2.1, y = 2, s = "Error: 2", color="#FF0000")
axis.text(x = 4.1, y = 4, s = "Error: -2", color="#FF0000")

# Las etiquetas
axis.set_xlabel('X', fontsize=15,labelpad=20,color="#003B80")  
axis.set_ylabel('Y', fontsize=15,labelpad=20,color="#003B80")
axis.set_title("Regresión lineal simple", fontsize=20,pad=30,color="#003B80")

vector_error = df.y - 3
print("Errores parciales (residuos): ")
print(vector_error)
error1 = sum(vector_error)

print("Error total: " + str(error1))
# Out:
# Errores parciales (residuos):
# 0   -2
# 1    0
# 2    2
# Name: y, dtype: int64
# Error total: 0

# %%
df = pd.read_csv("alturas.csv")

figure=plt.figure(figsize=(10, 5))
axis = figure.add_subplot()

# Las etiquetas
axis.set_xlabel('Alturas padres', fontsize=15,labelpad=20,color="#003B80")  
axis.set_ylabel('Alturas hijos', fontsize=15,labelpad=20,color="#003B80")
axis.set_title("Regresión lineal simple", fontsize=20,pad=30,color="#003B80")

x = np.arange(6)
y1 = [3, 3, 3, 3, 3, 3]

# Los datos que se muestran
axis.plot(df.Father, df.Son,"o",color="#0000FF", zorder = 1)
axis.hlines(y = 175, xmin = 145, xmax = 200, color = "#FF0000", zorder = 2)

# %%
df = pd.read_csv("alturas.csv")

figure=plt.figure(figsize=(10, 5))
axis = figure.add_subplot()

# Las etiquetas
axis.set_xlabel('Alturas padres', fontsize=15,labelpad=20,color="#003B80")  
axis.set_ylabel('Alturas hijos', fontsize=15,labelpad=20,color="#003B80")
axis.set_title("Regresión lineal simple", fontsize=20,pad=30,color="#003B80")

x = np.arange(6)
y1 = [3, 3, 3, 3, 3, 3]

# Los datos que se muestran
axis.plot(df.Father, df.Son,"o",color="#0000FF", zorder = 1)
axis.vlines(x = 171, ymin = 145, ymax = 200, color = "#FF0000", zorder = 2)
